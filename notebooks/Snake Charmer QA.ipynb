# %% [markdown]
# # Snake Charmer Quality Assurance Dept.
# ## _"All Your Eggs In One Basket"_
#
# Welcome to the Quality Assurance Department. Here you can run tests against Snake Charmer's components, in parallel, using roughly as many workers as you have vCPUs assigned to the VM. Actually, in practice we reduce this number slightly, as some test scripts start additional threads/processes themselves.
#
# **Warning:** This will take some time, even with lots of vCPUs, as some of the components' test suites take hours by themselves.
#
# The results will be written to `log/<hostname>/test_output` (relative to your `snake-charmer` directory).

# %% [markdown]
# ### Initialization

# %%
import subprocess
import functools
from concurrent.futures import ThreadPoolExecutor as Pool
import os
import shutil
import math

# TODO we'll need to use this for earlier versions of Python: https://pypi.python.org/pypi/futures

cpus = os.cpu_count()
workers = max(int(cpus * 0.75), 1)
pool = Pool(workers)

outdir = '/srv/log/test_output'
python = 'python3.4' # FIXME get this automatically

shutil.rmtree(outdir, ignore_errors=True)
os.makedirs(outdir, exist_ok=True)

def get_immediate_subdirectories(dir):
    return [name for name in os.listdir(dir)
            if os.path.isdir(os.path.join(dir, name))]

def make_cmd_line(name, command):
    return '%s > %s/%s.out 2>&1' % (command.replace('$PYTHON', python), outdir, name)

# These are tests to run in serial, as they handle their own parallelism perfectly well

# TODO work out how to make numba tests pass without sudo

serial_test_commands = [
    ('ipython', '$PYTHON `which iptest3` --all -j'),
    ('joblib', '$PYTHON `which nosetests` joblib'),
    ('numba', 'sudo $PYTHON -c "import numba; numba.testing.multitest()"')
]

# These are tests to run in parallel explicitly, after the serial tests have finished

# We generate individual submodule tests for sympy as they're so slow

def make_sympy_test_cmd(submod):
    return ('sympy_%s' % submod, '$PYTHON -c "import sympy; sympy.test(\'/%s\')"' % submod)

sympy_test_commands = [make_sympy_test_cmd(submod)
                       for submod in get_immediate_subdirectories('/usr/local/lib/%s/dist-packages/sympy' % python)
                       if not submod.startswith('_')]

parallel_test_commands = [
    ('pytables', '$PYTHON /usr/local/lib/$PYTHON/dist-packages/tables/tests/test_all.py --heavy'),
    ('cython', '(cd /srv/cache/src/Cython/ && $PYTHON runtests.py -vv)'),
    ('pymc', '$PYTHON -c "import pymc; pymc.test(\'full\')"'),
    ('theano', '$PYTHON `which theano-nose` --batch=100 --theano'),
    ('matplotlib', '$PYTHON -c "import matplotlib; matplotlib.test()"'),
    ('numpy', '$PYTHON -c "import numpy; numpy.test(\'full\')"'),
    ('scipy', '$PYTHON -c "import scipy; scipy.test(\'full\')"'),
    ('pandas', '$PYTHON `which nosetests` pandas'),
    ('sklearn', '$PYTHON `which nosetests` sklearn --exe'),
    ('pillow', '(cd /tmp && rm -f Images && ln -s /srv/cache/src/Pillow/Images . && $PYTHON /srv/cache/src/Pillow/selftest.py --installed)'),
    ('nltk', '$PYTHON /usr/local/lib/$PYTHON/dist-packages/nltk/test/runtests.py'),
    ('gensim', '(cd /srv/cache/src/gensim && $PYTHON setup.py test)'),
    ('bottleneck', '$PYTHON -c "import bottleneck as bn; bn.test(\'full\')"'),
    ('statsmodels', '$PYTHON -c "import statsmodels as sm; sm.test()"'),
    ('numexpr', '$PYTHON `which nosetests` numexpr'),
    ('patsy', '$PYTHON `which nosetests` patsy'),
    ('prettyplotlib', '(cd /srv/cache/src/prettyplotlib/tests && for py in $(ls test_*.py); do $PYTHON $py; done)')
] + sympy_test_commands

# %% [markdown]
# ### Serial tests

# %%
for name, command in serial_test_commands:
    cmd_line = make_cmd_line(name, command)
    print('\n\nExecuting %s:\t%s' % (name, cmd_line))
    rc = subprocess.call(cmd_line, shell=True, executable='/bin/bash')
    print('\n\n%s completed with status %d' % (name, rc))
# Out:
# Executing ipython:	python3.4 `which iptest3` --all -j > /srv/log/test_output/ipython.out 2>&1
#
#
# ipython completed with status 1
# Executing joblib:	python3.4 `which nosetests` joblib > /srv/log/test_output/joblib.out 2>&1
#
#
# joblib completed with status 0
# Executing numba:	sudo python3.4 -c "import numba; numba.testing.multitest()" > /srv/log/test_output/numba.out 2>&1
#
#
# numba completed with status 0

# %% [markdown]
# ### Parallel tests

# %%
def on_complete(name, future):
    if future.exception() is not None:
        print('\n\n%s FAILED!\n\n%s' % (name, future.exception()))
    else:
        print('\n\n%s completed with status %s' % (name, str(future.result())))
    # FIXME do these messages even go anywhere?

for name, command in parallel_test_commands:
    cmd_line = make_cmd_line(name, command)
    pool.submit(
        subprocess.call, cmd_line, shell=True, executable='/bin/bash'
    ).add_done_callback(
        functools.partial(on_complete, name))
    print('\n\nSubmitted %s:\t%s' % (name, cmd_line))

pool.shutdown(wait=True)

# TODO would be nice to get progress indicator as we go along
# Out:
# Submitted pytables:	python3.4 /usr/local/lib/python3.4/dist-packages/tables/tests/test_all.py --heavy > /srv/log/test_output/pytables.out 2>&1
#
#
# Submitted cython:	(cd /srv/cache/src/Cython/ && python3.4 runtests.py -vv) > /srv/log/test_output/cython.out 2>&1
#
#
# Submitted pymc:	python3.4 -c "import pymc; pymc.test('full')" > /srv/log/test_output/pymc.out 2>&1
#
#
# Submitted theano:	python3.4 `which theano-nose` --batch=100 --theano > /srv/log/test_output/theano.out 2>&1
#
#
# Submitted matplotlib:	python3.4 -c "import matplotlib; matplotlib.test()" > /srv/log/test_output/matplotlib.out 2>&1
#
#
# Submitted numpy:	python3.4 -c "import numpy; numpy.test('full')" > /srv/log/test_output/numpy.out 2>&1
#
#
# Submitted scipy:	python3.4 -c "import scipy; scipy.test('full')" > /srv/log/test_output/scipy.out 2>&1
#
#
# Submitted pandas:	python3.4 `which nosetests` pandas > /srv/log/test_output/pandas.out 2>&1
#
#
# Submitted sklearn:	python3.4 `which nosetests` sklearn --exe > /srv/log/test_output/sklearn.out 2>&1
#
#
# Submitted pillow:	(cd /tmp && rm -f Images && ln -s /srv/cache/src/Pillow/Images . && python3.4 /srv/cache/src/Pillow/selftest.py --installed) > /srv/log/test_output/pillow.out 2>&1
#
#
# Submitted nltk:	python3.4 /usr/local/lib/python3.4/dist-packages/nltk/test/runtests.py > /srv/log/test_output/nltk.out 2>&1
#
#
# Submitted gensim:	(cd /srv/cache/src/gensim && python3.4 setup.py test) > /srv/log/test_output/gensim.out 2>&1
#
#
# Submitted bottleneck:	python3.4 -c "import bottleneck as bn; bn.test('full')" > /srv/log/test_output/bottleneck.out 2>&1
#
#
# Submitted statsmodels:	python3.4 -c "import statsmodels as sm; sm.test()" > /srv/log/test_output/statsmodels.out 2>&1
#
#
# Submitted numexpr:	python3.4 `which nosetests` numexpr > /srv/log/test_output/numexpr.out 2>&1
#
#
# Submitted patsy:	python3.4 `which nosetests` patsy > /srv/log/test_output/patsy.out 2>&1
#
#
# Submitted prettyplotlib:	(cd /srv/cache/src/prettyplotlib/tests && for py in $(ls test_*.py); do python3.4 $py; done) > /srv/log/test_output/prettyplotlib.out 2>&1
#
#
# Submitted sympy_utilities:	python3.4 -c "import sympy; sympy.test('/utilities')" > /srv/log/test_output/sympy_utilities.out 2>&1
#
#
# Submitted sympy_series:	python3.4 -c "import sympy; sympy.test('/series')" > /srv/log/test_output/sympy_series.out 2>&1
#
#
# Submitted sympy_sets:	python3.4 -c "import sympy; sympy.test('/sets')" > /srv/log/test_output/sympy_sets.out 2>&1
#
#
# Submitted sympy_plotting:	python3.4 -c "import sympy; sympy.test('/plotting')" > /srv/log/test_output/sympy_plotting.out 2>&1
#
#
# Submitted sympy_integrals:	python3.4 -c "import sympy; sympy.test('/integrals')" > /srv/log/test_output/sympy_integrals.out 2>&1
#
#
# Submitted sympy_external:	python3.4 -c "import sympy; sympy.test('/external')" > /srv/log/test_output/sympy_external.out 2>&1
#
#
# Submitted sympy_mpmath:	python3.4 -c "import sympy; sympy.test('/mpmath')" > /srv/log/test_output/sympy_mpmath.out 2>&1
#
#
# Submitted sympy_logic:	python3.4 -c "import sympy; sympy.test('/logic')" > /srv/log/test_output/sympy_logic.out 2>&1
#
#
# Submitted sympy_calculus:	python3.4 -c "import sympy; sympy.test('/calculus')" > /srv/log/test_output/sympy_calculus.out 2>&1
#
#
# Submitted sympy_ntheory:	python3.4 -c "import sympy; sympy.test('/ntheory')" > /srv/log/test_output/sympy_ntheory.out 2>&1
#
#
# Submitted sympy_printing:	python3.4 -c "import sympy; sympy.test('/printing')" > /srv/log/test_output/sympy_printing.out 2>&1
#
#
# Submitted sympy_galgebra:	python3.4 -c "import sympy; sympy.test('/galgebra')" > /srv/log/test_output/sympy_galgebra.out 2>&1
#
#
# Submitted sympy_solvers:	python3.4 -c "import sympy; sympy.test('/solvers')" > /srv/log/test_output/sympy_solvers.out 2>&1
#
#
# Submitted sympy_categories:	python3.4 -c "import sympy; sympy.test('/categories')" > /srv/log/test_output/sympy_categories.out 2>&1
#
#
# Submitted sympy_functions:	python3.4 -c "import sympy; sympy.test('/functions')" > /srv/log/test_output/sympy_functions.out 2>&1
#
#
# Submitted sympy_diffgeom:	python3.4 -c "import sympy; sympy.test('/diffgeom')" > /srv/log/test_output/sympy_diffgeom.out 2>&1
#
#
# Submitted sympy_strategies:	python3.4 -c "import sympy; sympy.test('/strategies')" > /srv/log/test_output/sympy_strategies.out 2>&1
#
#
# Submitted sympy_crypto:	python3.4 -c "import sympy; sympy.test('/crypto')" > /srv/log/test_output/sympy_crypto.out 2>&1
#
#
# Submitted sympy_interactive:	python3.4 -c "import sympy; sympy.test('/interactive')" > /srv/log/test_output/sympy_interactive.out 2>&1
#
#
# Submitted sympy_polys:	python3.4 -c "import sympy; sympy.test('/polys')" > /srv/log/test_output/sympy_polys.out 2>&1
#
#
# Submitted sympy_stats:	python3.4 -c "import sympy; sympy.test('/stats')" > /srv/log/test_output/sympy_stats.out 2>&1
#
#
# Submitted sympy_concrete:	python3.4 -c "import sympy; sympy.test('/concrete')" > /srv/log/test_output/sympy_concrete.out 2>&1
#
#
# Submitted sympy_unify:	python3.4 -c "import sympy; sympy.test('/unify')" > /srv/log/test_output/sympy_unify.out 2>&1
#
#
# Submitted sympy_core:	python3.4 -c "import sympy; sympy.test('/core')" > /srv/log/test_output/sympy_core.out 2>&1
#
#
# Submitted sympy_combinatorics:	python3.4 -c "import sympy; sympy.test('/combinatorics')" > /srv/log/test_output/sympy_combinatorics.out 2>&1
#
#
# Submitted sympy_simplify:	python3.4 -c "import sympy; sympy.test('/simplify')" > /srv/log/test_output/sympy_simplify.out 2>&1
#
#
# Submitted sympy_assumptions:	python3.4 -c "import sympy; sympy.test('/assumptions')" > /srv/log/test_output/sympy_assumptions.out 2>&1
#
#
# Submitted sympy_matrices:	python3.4 -c "import sympy; sympy.test('/matrices')" > /srv/log/test_output/sympy_matrices.out 2>&1
#
#
# Submitted sympy_physics:	python3.4 -c "import sympy; sympy.test('/physics')" > /srv/log/test_output/sympy_physics.out 2>&1
#
#
# Submitted sympy_geometry:	python3.4 -c "import sympy; sympy.test('/geometry')" > /srv/log/test_output/sympy_geometry.out 2>&1
#
#
# Submitted sympy_liealgebras:	python3.4 -c "import sympy; sympy.test('/liealgebras')" > /srv/log/test_output/sympy_liealgebras.out 2>&1
#
#
# Submitted sympy_tensor:	python3.4 -c "import sympy; sympy.test('/tensor')" > /srv/log/test_output/sympy_tensor.out 2>&1
#
#
# Submitted sympy_parsing:	python3.4 -c "import sympy; sympy.test('/parsing')" > /srv/log/test_output/sympy_parsing.out 2>&1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-1f6b4c6421cc> in <module>()
#      14     print('\n\nSubmitted %s:\t%s' % (name, cmd_line))
#      15
# ---> 16 pool.shutdown(wait=True)
#      17
#      18 # TODO would be nice to get progress indicator as we go along
#
# /usr/lib/python3.4/concurrent/futures/thread.py in shutdown(self, wait)
#     129         if wait:
#     130             for t in self._threads:
# --> 131                 t.join()
#     132     shutdown.__doc__ = _base.Executor.shutdown.__doc__
#
# /usr/lib/python3.4/threading.py in join(self, timeout)
#    1059
#    1060         if timeout is None:
# -> 1061             self._wait_for_tstate_lock()
#    1062         else:
#    1063             # the behavior of a negative timeout isn't documented, but
#
# /usr/lib/python3.4/threading.py in _wait_for_tstate_lock(self, block, timeout)
#    1075         if lock is None:  # already determined that the C code is done
#    1076             assert self._is_stopped
# -> 1077         elif lock.acquire(block, timeout):
#    1078             lock.release()
#    1079             self._stop()
#
# KeyboardInterrupt:
